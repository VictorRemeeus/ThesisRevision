# %% [markdown]
# EDA

# %%
import pandas
import numpy

# %%
df = pandas.read_csv("G:\Master\Thesis revision\Datasets\\normal_EDA.csv")
meta_data = pandas.read_csv("G:\Master\Block 3\Thesis proposal\Scripts new\Metadata.csv", sep = ";")
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_12436\742455473.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_data = pandas.read_csv("G:\Master\Block 3\Thesis proposal\Scripts new\Metadata.csv", sep = ";")

# %%
meta_data
# Out:
#         App ID                            Name  \
# 0           10                  Counter-Strike
# 1      1000000                       ASCENXION
# 2      1000010                     Crown Trick
# 3      1000030     Cook, Serve, Delicious! 3?!
# 4      1000040                            细胞战争
# ...        ...                             ...
# 55686   999880     NASA's Exoplanet Excursions
# 55687   999890                          Bruken
# 55688   999900               Studio by RADiCAL
# 55689   999930  Fantasy Sino-Japanese War 幻想甲午
# 55690   999990                   Bouncing Hero
#
#                                        Short Description  \
# 0      Play the world's number 1 online action game. ...
# 1      ASCENXION is a 2D shoot 'em up game where you ...
# 2      Enter a labyrinth that moves as you move, wher...
# 3      Cook, serve and manage your food truck as you ...
# 4      这是一款打击感十足的细胞主题游戏！操作简单但活下去却不简单，“你”作为侵入人体的细菌病毒，通...
# ...

# %%
new_df = df.merge(meta_data, 'inner', left_on='V1', right_on= "App ID")

# %%
meta_data.columns
# Out:
# Index(['App ID', 'Name', 'Short Description', 'Developer', 'Publisher',
#        'Genre', 'Tags', 'Type', 'Categories', 'Owners', 'Positive Reviews',
#        'Negative Reviews', 'Price', 'Initial Price', 'Discount', 'CCU',
#        'Languages', 'Platforms', 'Release Date', 'Required Age', 'Website',
#        'Header Image'],
#       dtype='object')

# %%
new_df
# Out:
#            V1                                                 V2  V3  App ID  \
# 0      345820  cool great stage design awesome music pleasant...   0  345820
# 1      345820            unlike game you ll actually fun playing   0  345820
# 2      345820                                 logitech f do work   1  345820
# 3       40800                        fun achievement do not work   0   40800
# 4       40800              good platformer hard great soundtrack   0   40800
# ...       ...                                                ...  ..     ...
# 29027  267340  slow simplicistic weak tower defense do well i...   1  267340
# 29028  454550  think clean usefull program alot option hide d...   1  454550
# 29029  431850                      short end vague disappointing   1  431850
# 29030    2820           slow move sure people think develop good   1    2820
# 29031  234900                                know get metacritic   1  234900
#
#                                  Name  \
# ...

# %%
final_df = new_df[["V2", "Name", "Genre", "Release Date", "V3"]]

# %%
#adding character count
final_df["character count"] = final_df["V2"].str.len()
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_12436\1307732505.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df["character count"] = final_df["V2"].str.len()

# %%
final_df = final_df[final_df['V2'].apply(lambda x: len(str(x)) <151)]

# %%
final_df["Name"].value_counts()
# Out:
# PAYDAY 2                                           753
# Dota 2                                             529
# Terraria                                           389
# Grand Theft Auto V                                 328
# Left 4 Dead 2                                      266
#                                                   ...
# Kill to Collect                                      1
# Deliverance                                          1
# Magma Tsunami                                        1
# Broken Sword 2 - the Smoking Mirror: Remastered      1
# Anodyne                                              1
# Name: Name, Length: 3350, dtype: int64

# %%
final_df["Name"].nunique()
# Out:
# 3350

# %%
final_df["V3"].value_counts()
# Out:
# 0    14518
# 1    14512
# Name: V3, dtype: int64

# %%
final_df.to_csv("G:\Master\Thesis revision\Datasets\\EDA_edited.csv", index=False)
